# %% [markdown]
# Final Project Submission
#
#
# Student name:Elizabeth Nyambura
#
# Student pace:part time
#
# Scheduled project review date/time:
#
# Instructor name:Stella Waithira
#
# Blog post URL:https://github.com/elizabethnyambura/DSF-phase-1-project

# %%
#Importing the various modules to use for the project
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# loading the data sets

# %%
movie_gross=pd.read_csv('/content/bom.movie_gross.csv.gz')
idmb_title_basics=pd.read_csv('/content/imdb.title.basics.csv.gz')
imdb_title_ratings=pd.read_csv('/content/imdb.title.ratings.csv.gz')

# %% [markdown]
# we first need understand the data sets by checking the summary of each data

# %%
#Movie gross data set summary
movie_gross = pd.read_csv('/content/bom.movie_gross.csv.gz')
movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movie_gross = pd.read_csv('/content/bom.movie_gross.csv.gz')
movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
movie_gross.shape
# Out:
# (3387, 5)

# %%
movie_gross.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
#title basics data set summary
idmb_title_basics=pd.read_csv('/content/imdb.title.basics.csv.gz')
idmb_title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
idmb_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
idmb_title_basics.shape
# Out:
# (146144, 6)

# %%
idmb_title_basics.describe()
# Out:
#           start_year  runtime_minutes
# count  146144.000000    114405.000000
# mean     2014.621798        86.187247
# std         2.733583       166.360590
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2015.000000        87.000000
# 75%      2017.000000        99.000000
# max      2115.000000     51420.000000

# %%
#title ratings data set summary
imdb_title_ratings=pd.read_csv('/content/imdb.title.ratings.csv.gz')
imdb_title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
imdb_title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
imdb_title_ratings.shape
# Out:
# (73856, 3)

# %%
imdb_title_ratings.describe()
# Out:
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %% [markdown]
# Data cleaning to identify missing and duplicated data on the data sets

# %%
#movie gross data cleaning
movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
movie_gross.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
#drop studio and domestic gross NuN values
movie_gross.dropna(subset=['studio'],inplace=True)
movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
movie_gross.studio.isna().sum()
# Out:
# 0

# %%
movie_gross.dropna(subset=['domestic_gross'],inplace=True)
movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
movie_gross.domestic_gross.isna().sum()
# Out:
# 0

# %%
#foreign_gross data has 1350 missing values and therefore should not be dropped and  instead should most appropriately be replaced

# %%
#foreign gross being an object,we replace the missing values with zero
movie_gross['foreign_gross'].fillna(0, inplace=True)
movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
#check if foreign_gross has missing values
movie_gross["foreign_gross"].isna().sum()
# Out:
# 0

# %%
#Ascertain duplicate data on movie_gross data
movie_gross.duplicated().sum()
# Out:
# 0

# %%
movie_gross.shape
# Out:
# (3356, 5)

# %%
#idmb_title_basics data cleaning
idmb_title_basics=pd.read_csv('/content/imdb.title.basics.csv.gz')
idmb_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
idmb_title_basics.isnull().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
#drop original_title missing values
idmb_title_basics.dropna(subset=['original_title'], inplace=True)
idmb_title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
idmb_title_basics["original_title"].isna().sum()
# Out:
# 0

# %%
#drop genres missing values
idmb_title_basics.dropna(subset=['genres'], inplace=True)
idmb_title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146138  tt9916428                          The Secret of China
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
idmb_title_basics["genres"].isna().sum()
# Out:
# 0

# %%
#runtime_minutes missing data constitutes a substantial portion of the dataset and therefore cannot be dropped
#To determine whether to replace missing values with the median, mean, mode, or 0, the initial step involves verifying the data type we are handling.

idmb_title_basics['runtime_minutes'].dtype
# Out:
# dtype('float64')

# %%
#Since the data is a float, we have the capability to calculate various statistical measures or commands to handle missing values.
#Hence, we find the median value and replace the missing values with the median
median_runtime_minutes=idmb_title_basics['runtime_minutes'].median()
median_runtime_minutes
# Out:
# 87.0

# %%
idmb_title_basics['runtime_minutes'].fillna(idmb_title_basics['runtime_minutes'].median(), inplace=True)
idmb_title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146138  tt9916428                          The Secret of China
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#Acertain runtime_minutes does not have missing values
idmb_title_basics["runtime_minutes"].isna().sum()
# Out:
# 0

# %%
idmb_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140734 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           140734 non-null  object
#  1   primary_title    140734 non-null  object
#  2   original_title   140734 non-null  object
#  3   start_year       140734 non-null  int64
#  4   runtime_minutes  140734 non-null  float64
#  5   genres           140734 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 7.5+ MB

# %%
#check for duplicates in data
idmb_title_basics.duplicated().sum()
# Out:
# 0

# %%
#imdb_title_ratings data cleaning
#checking for missing values
imdb_title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
#check availability of duplicated values
imdb_title_ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# imdb_title_ratings data does not have neither missing values nor duplicated values

# %% [markdown]
# Data Aggregation

# %%
movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
idmb_title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018             87.0          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %% [markdown]
# idmb_title_basics and imdb_title_ratings have a common column,tconst, and therefore we merge the two data sets using the inner join

# %%
joined_imdb_df = idmb_title_basics.merge(imdb_title_ratings, on='tconst', how='inner')
joined_imdb_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018             87.0          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
movie_gross.rename({'title': 'primary_title'}, axis=1, inplace=True)
movie_gross.head()
# Out:
#                                  primary_title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movie_gross.set_index('primary_title', inplace=True)

# %%
joined_imdb_df1=joined_imdb_df.merge(movie_gross, on='primary_title', how='inner')
joined_imdb_df1.head()
# Out:
#       tconst                    primary_title  \
# 0  tt0315642                            Wazir
# 1  tt0337692                      On the Road
# 2  tt4339118                      On the Road
# 3  tt5647250                      On the Road
# 4  tt0359950  The Secret Life of Walter Mitty
#
#                     original_title  start_year  runtime_minutes  \
# 0                            Wazir        2016            103.0
# 1                      On the Road        2012            124.0
# 2                      On the Road        2014             89.0
# 3                      On the Road        2016            121.0
# 4  The Secret Life of Walter Mitty        2013            114.0
#
#                     genres  averagerating  numvotes   studio  domestic_gross  \
# 0       Action,Crime,Drama            7.1     15378  Relbig.       1100000.0
# 1  Adventure,Drama,Romance            6.1     37886      IFC        744000.0
# ...

# %%
joined_imdb_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2997 entries, 0 to 2996
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           2997 non-null   object
#  1   primary_title    2997 non-null   object
#  2   original_title   2997 non-null   object
#  3   start_year       2997 non-null   int64
#  4   runtime_minutes  2997 non-null   float64
#  5   genres           2997 non-null   object
#  6   averagerating    2997 non-null   float64
#  7   numvotes         2997 non-null   int64
#  8   studio           2997 non-null   object
#  9   domestic_gross   2997 non-null   float64
#  10  foreign_gross    2997 non-null   object
#  11  year             2997 non-null   int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 304.4+ KB

# %%
joined_imdb_df1.shape
# Out:
# (2997, 12)

# %%
#check for duplicated values
joined_imdb_df1.duplicated().sum()
# Out:
# 0

# %%
#dropping duplicated columns
joined_imdb_df1=joined_imdb_df1.drop(columns = ['original_title'])
joined_imdb_df1.head()
# Out:
#       tconst                    primary_title  start_year  runtime_minutes  \
# 0  tt0315642                            Wazir        2016            103.0
# 1  tt0337692                      On the Road        2012            124.0
# 2  tt4339118                      On the Road        2014             89.0
# 3  tt5647250                      On the Road        2016            121.0
# 4  tt0359950  The Secret Life of Walter Mitty        2013            114.0
#
#                     genres  averagerating  numvotes   studio  domestic_gross  \
# 0       Action,Crime,Drama            7.1     15378  Relbig.       1100000.0
# 1  Adventure,Drama,Romance            6.1     37886      IFC        744000.0
# 2                    Drama            6.0         6      IFC        744000.0
# 3                    Drama            5.7       127      IFC        744000.0
# 4   Adventure,Comedy,Drama            7.3    275300      Fox      58200000.0
#
#   foreign_gross  year
# 0             0  2016
# ...

# %%
#dropping unwanted columns
joined_imdb_df1=joined_imdb_df1.drop(columns = ['tconst' , 'runtime_minutes' , 'numvotes' , 'year'])
joined_imdb_df1
# Out:
#                         primary_title  start_year                   genres  \
# 0                               Wazir        2016       Action,Crime,Drama
# 1                         On the Road        2012  Adventure,Drama,Romance
# 2                         On the Road        2014                    Drama
# 3                         On the Road        2016                    Drama
# 4     The Secret Life of Walter Mitty        2013   Adventure,Comedy,Drama
# ...                               ...         ...                      ...
# 2992                  The Chambermaid        2018                    Drama
# 2993           How Long Will I Love U        2018                  Romance
# 2994                  Helicopter Eela        2018                    Drama
# 2995                      Last Letter        2018            Drama,Romance
# 2996        Burn the Stage: The Movie        2018        Documentary,Music
#
#       averagerating     studio  domestic_gross foreign_gross
# ...

# %%
joined_imdb_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2997 entries, 0 to 2996
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   primary_title   2997 non-null   object
#  1   start_year      2997 non-null   int64
#  2   genres          2997 non-null   object
#  3   averagerating   2997 non-null   float64
#  4   studio          2997 non-null   object
#  5   domestic_gross  2997 non-null   float64
#  6   foreign_gross   2997 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 187.3+ KB

# %%
#convert foreign_ gross to a float to enable calculation of total gross
joined_imdb_df1['foreign_gross']=joined_imdb_df1['foreign_gross'].str.replace(',' ,'').apply(float)

# %%
joined_imdb_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2997 entries, 0 to 2996
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   primary_title   2997 non-null   object
#  1   start_year      2997 non-null   int64
#  2   genres          2997 non-null   object
#  3   averagerating   2997 non-null   float64
#  4   studio          2997 non-null   object
#  5   domestic_gross  2997 non-null   float64
#  6   foreign_gross   1803 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 187.3+ KB

# %%
#find the total gross generated
total_gross_income = (joined_imdb_df1['domestic_gross'] + joined_imdb_df1['foreign_gross'])
total_gross_income.value_counts()
# Out:
# 59300000.0     7
# 43000000.0     7
# 14900000.0     6
# 278500000.0    6
# 39300000.0     6
#               ..
# 12729000.0     1
# 117000000.0    1
# 4448000.0      1
# 622700.0       1
# 82847000.0     1
# Length: 1334, dtype: int64

# %%
#create total gross income column
joined_imdb_df1 = joined_imdb_df1.eval('total_gross_income = domestic_gross + foreign_gross')
joined_imdb_df1.head()
# Out:
#                      primary_title  start_year                   genres  \
# 0                            Wazir        2016       Action,Crime,Drama
# 1                      On the Road        2012  Adventure,Drama,Romance
# 2                      On the Road        2014                    Drama
# 3                      On the Road        2016                    Drama
# 4  The Secret Life of Walter Mitty        2013   Adventure,Comedy,Drama
#
#    averagerating   studio  domestic_gross  foreign_gross  total_gross_income
# 0            7.1  Relbig.       1100000.0            NaN                 NaN
# 1            6.1      IFC        744000.0      8000000.0           8744000.0
# 2            6.0      IFC        744000.0      8000000.0           8744000.0
# 3            5.7      IFC        744000.0      8000000.0           8744000.0
# 4            7.3      Fox      58200000.0    129900000.0         188100000.0

# %%
#Ascertain missing values on total_gross_income
joined_imdb_df1['total_gross_income'].isna().sum()
# Out:
# 1194

# %%
joined_imdb_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2997 entries, 0 to 2996
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   primary_title       2997 non-null   object
#  1   start_year          2997 non-null   int64
#  2   genres              2997 non-null   object
#  3   averagerating       2997 non-null   float64
#  4   studio              2997 non-null   object
#  5   domestic_gross      2997 non-null   float64
#  6   foreign_gross       1803 non-null   float64
#  7   total_gross_income  1803 non-null   float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 210.7+ KB

# %%
#foreign_gross and total_gross_income are a float data types,hence,fill missing values using median
median=joined_imdb_df1['foreign_gross'].median()
median
# Out:
# 21300000.0

# %%
joined_imdb_df1['foreign_gross'].fillna(joined_imdb_df1['foreign_gross'].median(), inplace=True)
joined_imdb_df1.head()
# Out:
#                      primary_title  start_year                   genres  \
# 0                            Wazir        2016       Action,Crime,Drama
# 1                      On the Road        2012  Adventure,Drama,Romance
# 2                      On the Road        2014                    Drama
# 3                      On the Road        2016                    Drama
# 4  The Secret Life of Walter Mitty        2013   Adventure,Comedy,Drama
#
#    averagerating   studio  domestic_gross  foreign_gross  total_gross_income
# 0            7.1  Relbig.       1100000.0     21300000.0                 NaN
# 1            6.1      IFC        744000.0      8000000.0           8744000.0
# 2            6.0      IFC        744000.0      8000000.0           8744000.0
# 3            5.7      IFC        744000.0      8000000.0           8744000.0
# 4            7.3      Fox      58200000.0    129900000.0         188100000.0

# %%
#confirm foreign_gross has no missing values

joined_imdb_df1.foreign_gross.isna().sum()
# Out:
# 0

# %%
median=joined_imdb_df1['total_gross_income'].median()
median
# Out:
# 48100000.0

# %%
joined_imdb_df1['total_gross_income'].fillna(joined_imdb_df1['total_gross_income'].median(), inplace=True)
joined_imdb_df1.head()
# Out:
#                      primary_title  start_year                   genres  \
# 0                            Wazir        2016       Action,Crime,Drama
# 1                      On the Road        2012  Adventure,Drama,Romance
# 2                      On the Road        2014                    Drama
# 3                      On the Road        2016                    Drama
# 4  The Secret Life of Walter Mitty        2013   Adventure,Comedy,Drama
#
#    averagerating   studio  domestic_gross  foreign_gross  total_gross_income
# 0            7.1  Relbig.       1100000.0     21300000.0          48100000.0
# 1            6.1      IFC        744000.0      8000000.0           8744000.0
# 2            6.0      IFC        744000.0      8000000.0           8744000.0
# 3            5.7      IFC        744000.0      8000000.0           8744000.0
# 4            7.3      Fox      58200000.0    129900000.0         188100000.0

# %%
#confirm total_gross_income has no missing values

joined_imdb_df1.total_gross_income.isna().sum()
# Out:
# 0

# %% [markdown]
# DATA VISUALIZATION

# %% [markdown]
#  relationship between genres and total gross income

# %%
most_profitable_genres = joined_imdb_df1.groupby('genres')['total_gross_income'].sum()[:10]
most_profitable_genres = most_profitable_genres.sort_values(ascending=False)
most_profitable_genres
# Out:
# genres
# Action,Adventure,Fantasy      1.331489e+10
# Action,Adventure,Comedy       1.000181e+10
# Action,Adventure,Animation    6.678615e+09
# Action,Adventure,Drama        5.694243e+09
# Action,Adventure,Crime        1.608157e+09
# Action,Adventure,Family       1.508900e+09
# Action                        1.060958e+09
# Action,Adventure,Horror       1.011500e+09
# Action,Adventure,Biography    8.283290e+08
# Action,Adventure              1.964835e+08
# Name: total_gross_income, dtype: float64

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

width = 0.4

most_profitable_genres.plot(kind='bar', color='blue', ax=ax, width=width, position=1)

ax.legend()
plt.xlabel('Top ten Profitable Genres')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# As per the above graph, Action adventureFantasy have the highest gross income while Action Adventure have the least gross income.

# %% [markdown]
# Relationship between Genres and Studio

# %%
most_profitable_studios = joined_imdb_df1.groupby('studio')['total_gross_income'].sum()[:10]
most_profitable_studios
# Out:
# studio
# 3D     1.600000e+07
# A23    9.620000e+07
# A24    1.761378e+09
# ADC    9.620000e+07
# AF     2.487000e+08
# AGF    1.768000e+05
# ALP    9.620000e+07
# AM     4.810000e+07
# AR     5.805000e+07
# ATO    9.885570e+07
# Name: total_gross_income, dtype: float64

# %%
#Plot a bar graph to view and analyze the distribution and determine the best studio to invest in

fig = plt.figure(figsize=(14, 6))
ax = fig.add_subplot(111)

width = 0.5

most_profitable_studios.plot(kind='bar', color= 'green', ax=ax, width=width, position=1)
plt.xlabel('Studio', fontsize = 16)
plt.ylabel('Frequency', fontsize = 16)
ax.set_title("most Profitable Studios", fontsize = 16)

ax.legend()
plt.show()

# %% [markdown]
# As per the above graph,A24 studio has the highest returns in terms of total gross income while 3D studio and AGF studio has the least and no returns respectively.It is therefore advisable for Microsoft to invest in the A24 studio

# %% [markdown]
# movies Genre with the highest average rating

# %%
genres_rating = joined_imdb_df1.groupby('genres')['averagerating'].mean().sort_values(ascending = False)
genres_rating.head()
# Out:
# genres
# Adventure                       9.2
# Action,Sport                    8.4
# Adventure,Drama,Sci-Fi          8.3
# Biography,Documentary,Family    8.3
# Documentary,Sport               8.2
# Name: averagerating, dtype: float64

# %%
#bar graph showing the average rating by genre
fig, ax =plt.subplots(figsize=(14,6))
order_by = joined_imdb_df1.groupby('genres')['averagerating'].mean().sort_values(ascending=False).index
sns.barplot(data=joined_imdb_df1, x='genres', y= 'averagerating', palette='muted', order=order_by, ax=ax)
ax.set_title('Average rating by genre')
ax.set_ylabel('average rating')
plt.xticks(rotation=60);

# %% [markdown]
# As per the above analysis,Adventure, action,Sport and Adventure,Drama,Sci-Fi have the highest ratings while Documentary,Sport have the lowest rating

# %% [markdown]
# Relationship between the average rating and the gross income

# %%
#scatter plot showing  total gross vs average rating
fig, ax =plt.subplots(figsize=(11,6))
sns.scatterplot(x=joined_imdb_df1['averagerating'], y=joined_imdb_df1['total_gross_income'], ax=ax)
ax.set_title('total gross vs average rating')
ax.set_ylabel('total gross income')
ax.set_xlabel('average rating');

# %% [markdown]
# As per the above analysis,there is no clear relationship between average rating and total gross rating and therefore this relationship should not be used for decision making on the business investment

# %% [markdown]
# Relationship between Gross income and start year

# %%
#lineplot showing the domestic gross and foreign gross income by start year
fig, ax =plt.subplots(figsize=(15,7))
sns.lineplot(data=joined_imdb_df1, x='start_year', y='domestic_gross', ax=ax, label='domestic_gross')
sns.lineplot(data=joined_imdb_df1, x='start_year', y='foreign_gross', label='foreign_gross', ax=ax)
ax.set_title('total_gross_income by start year')
ax.set_ylabel('total_gross_income');

# %% [markdown]
# The foreign gross income is constantly higher than the domestic gross income throughout the years when a movie is released.
# Movies that were released in 2018 had the highest foreign gross and domestic gross income.The gross incomes then drastically dropped to their lowest for movies that were released in 2019.

# %% [markdown]
# CONCLUSION

# %% [markdown]
# Action,adventure and Fantasy have the highest gross income while Action Adventure Biography have the least gross income.Therefore it would be advisable for Microsoft to invest in Action,Adventure and Fantasy Genres.
# A24 studio has the highest returns in terms of total gross income and therefore,it is advisable for Microsoft to invest in the A24 studio.
# Adventure,Action,Sport and Adventure,Drama,Sci-Fi have the highest average ratings while Documentary,Sport have the lowest average ratings.However,there is no clear relationship between average rating and total gross rating and therefore this relationship should not be used for decision making on business investment.
# The foreign gross income is constantly higher than the domestic gross income throughout the years when a movie is released.For intance Movies that were released in 2018 had the highest foreign gross and domestic gross income.The gross incomes then drastically dropped to their lowest for movies that were released in 2019.Hence,Microsoft should focus more on exploring  the international markets and produce movies with more focus on international interests.

# %% [markdown]
# RECOMMENDATION

# %% [markdown]
# Further market study is necessary to ascertain the optimal timing for releasing a movie of a particular genre.
# Determining whether the total gross income of a genre experiences proportional growth with increased budgets for production, development, marketing, and advertising is crucial for profit prediction based on the budget.
# In addition to box office earnings, studios generate revenue from various sources such as home entertainment sales and rentals, television rights, product placement fees, and streaming services. Collecting data on these revenue streams and comparing them to theatrical earnings is essential for a comprehensive financial analysis and decision-making for investment purposes.
